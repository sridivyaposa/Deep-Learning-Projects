# %% [markdown]
# <a href="https://colab.research.google.com/github/sridivyaposa/Deep-Learning-Projects/blob/master/TableDetectionUsingMaskRCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Table detection using MaskRCNN
#
# This notebook can be employed to detect tables in images using a MaskRCNN detection model.
#
# We need to install some libraries and download some files that are required to run the MaskRCNN model by executing the following cells. We also download some images for testing.

# %%
# !git clone https://github.com/matterport/Mask_RCNN/
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 111.81 MiB | 28.52 MiB/s, done.
# Resolving deltas: 100% (571/571), done.

# %%
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/mask-rcnn/predict.py -O predict.py
# !wget https://www.dropbox.com/s/dcl53rl3xqndfdx/mask_rcnn_tablebank_cfg_0002.h5?dl=0 -O mask_rcnn_tablebank_cfg_0002.h5
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100058.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100171.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100183.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100341.jpg
# !wget https://raw.githubusercontent.com/holms-ur/fine-tuning/master/images/Latex_100491.jpg
# Out:
# --2019-11-14 07:58:28--  https://raw.githubusercontent.com/holms-ur/fine-tuning/master/code/mask-rcnn/predict.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1654 (1.6K) [text/plain]
# Saving to: ‘predict.py’
#
# predict.py          100%[===================>]   1.62K  --.-KB/s    in 0s
#
# 2019-11-14 07:58:28 (25.5 MB/s) - ‘predict.py’ saved [1654/1654]
#
# --2019-11-14 07:58:30--  https://www.dropbox.com/s/dcl53rl3xqndfdx/mask_rcnn_tablebank_cfg_0002.h5?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.1, 2620:100:6021:1::a27d:4101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# ...

# %%
cd Mask_RCNN/
# Out:
# /content/Mask_RCNN

# %%
# !pip install . --user
# Out:
# Processing /content/Mask_RCNN
# ...
#   Created wheel for mask-rcnn: filename=mask_rcnn-2.1-cp36-none-any.whl size=56923 sha256=9f7d9efb06d492e68b1a0c33acb58b05e1410b2e8d3cd9ca634020b1e3344c74
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xx_rvyd3/wheels/78/da/b4/63931b0b9847ef98ac88d2b032817246adcf667c5da577133f
# Successfully built mask-rcnn
# ...

# %% [markdown]
# You need to restart the execution environment.

# %%
import os
os.kill(os.getpid(), 9)

# %% [markdown]
# Once the above files are downloaded, we can load the functionality to detect ablaes in the images, and some additional libraries that are necessary for uploading your images.

# %%
from predict import predict,showImage
from google.colab import files
import cv2

# %% [markdown]
# You can upload your own images by using the left side menu, and detect the tables with the following command where you can change the name of the image.

# %%
# %%time
predict("Latex_100058.jpg")
# Out:
# CPU times: user 3.88 s, sys: 1.75 s, total: 5.63 s
# Wall time: 7.95 s

# %% [markdown]
# Now, we show the result inside the notebook.

# %%
image = cv2.imread('prediction.jpg')
showImage(image)

# %% [markdown]
# It is also possible to download the image from the Files menu on the left side of the browser.

# %% [markdown]
# Other examples.

# %%
predict("Latex_100171.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)

# %%
predict("Latex_100183.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)

# %%
predict("Latex_100341.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)

# %%
predict("Latex_100491.jpg")
image = cv2.imread('prediction.jpg')
showImage(image)
